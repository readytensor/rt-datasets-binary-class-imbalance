# %%
import numpy as np
import pandas as pd
import os

# %%
dataset_name = 'image_segmentation'

# %%
input_dir = './raw'
inp_fname = 'segment.csv'
output_dir = f'./../../processed/{dataset_name}/'
outp_fname = os.path.join(output_dir, f'{dataset_name}.csv')

# %% [markdown]
# # Read Data

# %%
data = pd.read_csv(os.path.join(input_dir, inp_fname))
data.head()
# Out:
#    region-centroid-col  region-centroid-row  region-pixel-count  \
# 0                  218                  178                   9
# 1                  113                  130                   9
# 2                  202                   41                   9
# 3                   32                  173                   9
# 4                   61                  197                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean  vegde-sd  \
# 0              0.111111                   0.0    0.833333  0.547722
# 1              0.000000                   0.0    0.277778  0.250924
# 2              0.000000                   0.0    0.944448  0.772202
# 3              0.000000                   0.0    1.722220  1.781590
# 4              0.000000                   0.0    1.444440  1.515350
#
#    hedge-mean  hedge-sd  intensity-mean  rawred-mean  rawblue-mean  \
# 0    1.111110  0.544331       59.629600      52.4444      75.22220
# 1    0.333333  0.365148        0.888889       0.0000       2.55556
# 2    1.111110  1.025600      123.037000     111.8890     139.77800
# 3    9.000000  6.749490       43.592600      39.5556      52.88890
# 4    2.611110  1.925460       49.592600      44.2222      61.55560
#
#    rawgreen-mean  exred-mean  exblue-mean  exgreen-mean  value-mean  \
# 0      51.222200   -21.55560      46.7778     -25.22220    75.22220
# 1       0.111111    -2.66667       5.0000      -2.33333     2.55556
# 2     117.444000   -33.44440      50.2222     -16.77780   139.77800
# 3      38.333300   -12.11110      27.8889     -15.77780    52.88890
# 4      43.000000   -16.11110      35.8889     -19.77780    61.55560
#
#    saturation-mean  hue-mean binaryClass
# 0         0.318996  -2.04055           N
# 1         1.000000  -2.12325           N
# 2         0.199347  -2.29992           N
# 3         0.266914  -1.99886           N
# 4         0.302925  -2.02227           N

# %%
id_col = "id"
target_col = "binaryClass"

# %% [markdown]
# # Insert Id Column

# %%
# insert Id column 
if id_col not in data.columns:
    N = data.shape[0]
    data.insert(0, id_col, np.arange(N))
    print(data.head())

data[id_col] = data[id_col].astype(str)
# Out:
#    id  region-centroid-col  region-centroid-row  region-pixel-count  \
# 0   0                  218                  178                   9
# 1   1                  113                  130                   9
# 2   2                  202                   41                   9
# 3   3                   32                  173                   9
# 4   4                   61                  197                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean  vegde-sd  \
# 0              0.111111                   0.0    0.833333  0.547722
# 1              0.000000                   0.0    0.277778  0.250924
# 2              0.000000                   0.0    0.944448  0.772202
# 3              0.000000                   0.0    1.722220  1.781590
# 4              0.000000                   0.0    1.444440  1.515350
#
#    hedge-mean  hedge-sd  ...  rawred-mean  rawblue-mean  rawgreen-mean  \
# 0    1.111110  0.544331  ...      52.4444      75.22220      51.222200
# 1    0.333333  0.365148  ...       0.0000       2.55556       0.111111
# 2    1.111110  1.025600  ...     111.8890     139.77800     117.444000
# 3    9.000000  6.749490  ...      39.5556      52.88890      38.333300
# 4    2.611110  1.925460  ...      44.2222      61.55560      43.000000
#
#    exred-mean  exblue-mean  exgreen-mean  value-mean  saturation-mean  \
# 0   -21.55560      46.7778     -25.22220    75.22220         0.318996
# 1    -2.66667       5.0000      -2.33333     2.55556         1.000000
# 2   -33.44440      50.2222     -16.77780   139.77800         0.199347
# 3   -12.11110      27.8889     -15.77780    52.88890         0.266914
# 4   -16.11110      35.8889     -19.77780    61.55560         0.302925
#
#    hue-mean  binaryClass
# 0  -2.04055            N
# 1  -2.12325            N
# 2  -2.29992            N
# 3  -1.99886            N
# 4  -2.02227            N
#
# [5 rows x 21 columns]

# %% [markdown]
# # Save Main Data File

# %%
data.to_csv(outp_fname, index=False)
